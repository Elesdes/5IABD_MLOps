# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization (e.g plot graphs)
import seaborn as sns #  creates informative statistical graphics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import tensorflow as tf # building and training neural networks
import xgboost as xgb # for building and training neural networks
import os

# %% [markdown]
# Loading and examining the data:

# %%
df = pd.read_csv('../input/electromyography-emg-dataset/Electro-Myography-EMG-Dataset/extracted_features_and_labeled_dataset(easiest to work with)/emg_all_features_labeled.csv')
raw = pd.read_csv('../input/electromyography-emg-dataset/Electro-Myography-EMG-Dataset/raw_emg_data_unprocessed/index_finger_motion_raw.csv')
# print(df.head())
print(df.shape, raw.shape)
# print(df.describe)

df.describe() # describes the data
# Out:
# (6822, 81) (223793, 8)
#           0.029437     0.051465     0.089432     0.016893     0.014127  \
# count  6822.000000  6822.000000  6822.000000  6822.000000  6822.000000
# mean      0.040823     0.065489     0.097874     0.036480     0.024884
# std       0.039008     0.055671     0.098010     0.029872     0.017541
# min       0.006165     0.006814     0.006432     0.006443     0.006949
# 25%       0.015790     0.027960     0.034170     0.017518     0.013873
# 50%       0.027571     0.050213     0.059132     0.025909     0.020272
# 75%       0.049174     0.084064     0.122622     0.046268     0.030887
# max       0.309780     0.419220     0.487810     0.245450     0.221130
#
#           0.017735     0.019645     0.014079     0.030692     0.052209  ...  \
# count  6822.000000  6822.000000  6822.000000  6822.000000  6822.000000  ...
# mean      0.045121     0.099462     0.054163     0.042424     0.066619  ...
# std       0.044636     0.109739     0.066580     0.038112     0.054745  ...
# min       0.006798     0.006615     0.006122     0.010712     0.011779  ...
# 25%       0.019946     0.019318     0.014736     0.018266     0.029564  ...
# 50%       0.031550     0.052236     0.026368     0.029022     0.051035  ...
# 75%       0.053941     0.139770     0.063585     0.049878     0.084332  ...
# max       0.459510     0.548000     0.432420     0.308750     0.417830  ...
#
#             2.3516            2            3            6            0  \
# count  6822.000000  6822.000000  6822.000000  6822.000000  6822.000000
# mean      8.709442     2.051305     3.880094     4.994723     1.738053
# std      11.202169     2.727362     3.367661     3.830100     2.516240
# min       0.945310     0.000000     0.000000     0.000000     0.000000
# 25%       2.421900     0.000000     1.000000     2.000000     0.000000
# 50%       4.085900     1.000000     3.000000     5.000000     0.000000
# 75%       9.753900     3.000000     6.000000     8.000000     3.000000
# max      78.719000    13.000000    14.000000    14.000000    13.000000
#
#                0.1            1          1.1          0.2          1.2
# count  6822.000000  6822.000000  6822.000000  6822.000000  6822.000000
# mean      0.733656     2.194811     4.317942     2.604955     3.847112
# std       1.432499     2.544202     4.110435     3.412000     1.962840
# min       0.000000     0.000000     0.000000     0.000000     1.000000
# 25%       0.000000     0.000000     0.000000     0.000000     2.000000
# 50%       0.000000     1.000000     3.000000     1.000000     4.000000
# 75%       1.000000     4.000000     8.000000     4.000000     5.000000
# max      11.000000    14.000000    14.000000    14.000000     7.000000
#
# [8 rows x 81 columns]

# %% [markdown]
# Data visualization:

# %%
def plot_data(data):    
    fig, axes = plt.subplots(2,4, figsize=(30, 8), sharex=True, sharey=True) # ensures that all subplots share the same x-axis and y-axis
    for i in range(2):
        for j in range(4):
            axes[i][j].plot(data.iloc[:,i*j])
        
plot_data(raw)

# %% [markdown]
# Data preprocessing:

# %%
x = df.iloc[:,:80].copy()
y = df.iloc[:,80].copy()
print(x.shape)
print(y.shape)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=1) # Split data for test and training
# Out:
# (6822, 80)
# (6822,)

# %%
SC = StandardScaler()
x_train = pd.DataFrame(SC.fit_transform(x_train))
x_test = pd.DataFrame(SC.transform(x_test))

# %% [markdown]
# Model training and evaluation:

# %%
model_XGB = xgb.XGBClassifier()
model_RF = RandomForestClassifier(n_estimators = 100, random_state=1)
model_XGB.fit(x_train, y_train)
model_RF.fit(x_train, y_train)
# Out:
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [09:29:00] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# RandomForestClassifier(random_state=1)

# %%
y_pred = model_RF.predict(x_test)
y_p = model_XGB.predict(x_test)
accuracy = accuracy_score(y_test, [q for q in y_pred])
accuracy_p = accuracy_score(y_test, [r for r in y_p])
print("Accuracy for RF: %.2f%%" % (accuracy * 100.0))
print("Accuracy for XGB: %.2f%%" % (accuracy_p * 100.0))
# Out:
# Accuracy for RF: 94.37%
# Accuracy for XGB: 94.67%

# %% [markdown]
# Creating a neural network model:

# %%
inputs = tf.keras.Input(shape=(x.shape[1],))
x = tf.keras.layers.Dense(80, activation='relu')(inputs)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(80, activation='relu')(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = tf.keras.layers.Dense(8, activation='softmax')(x)

model_cnn = tf.keras.Model(inputs, outputs)

# %%
model_cnn.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

batch_size = 32
epochs = 50

history = model_cnn.fit(
    x_train,
    y_train,
    validation_split=0.2,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=[
        tf.keras.callbacks.ReduceLROnPlateau()
    ]
)
# Out:
# Epoch 1/50
# 128/128 [==============================] - 2s 6ms/step - loss: 1.0658 - accuracy: 0.6442 - val_loss: 0.5387 - val_accuracy: 0.8271
# Epoch 2/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5831 - accuracy: 0.7906 - val_loss: 0.4153 - val_accuracy: 0.8555
# Epoch 3/50
# 128/128 [==============================] - 0s 4ms/step - loss: 0.4915 - accuracy: 0.8304 - val_loss: 0.3723 - val_accuracy: 0.8750
# Epoch 4/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.4257 - accuracy: 0.8522 - val_loss: 0.3308 - val_accuracy: 0.8730
# Epoch 5/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.4050 - accuracy: 0.8565 - val_loss: 0.3058 - val_accuracy: 0.8926
# Epoch 6/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.3749 - accuracy: 0.8693 - val_loss: 0.2971 - val_accuracy: 0.8945
# Epoch 7/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.3468 - accuracy: 0.8759 - val_loss: 0.2948 - val_accuracy: 0.8848
# Epoch 8/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.3251 - accuracy: 0.8847 - val_loss: 0.2661 - val_accuracy: 0.9023
# Epoch 9/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.2959 - accuracy: 0.8981 - val_loss: 0.2567 - val_accuracy: 0.9033
# Epoch 10/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.3101 - accuracy: 0.8847 - val_loss: 0.2441 - val_accuracy: 0.9053
# Epoch 11/50
# 128/128 [==============================] - 0s 4ms/step - loss: 0.2869 - accuracy: 0.9003 - val_loss: 0.2470 - val_accuracy: 0.9072
# Epoch 12/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.2758 - accuracy: 0.9057 - val_loss: 0.2390 - val_accuracy: 0.9180
# Epoch 13/50
# 128/128 [==============================] - 0s 4ms/step - loss: 0.2588 - accuracy: 0.9103 - val_loss: 0.2329 - val_accuracy: 0.9160
# Epoch 14/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.2550 - accuracy: 0.9132 - val_loss: 0.2252 - val_accuracy: 0.9160
# Epoch 15/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.2388 - accuracy: 0.9142 - val_loss: 0.2214 - val_accuracy: 0.9229
# Epoch 16/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.2333 - accuracy: 0.9201 - val_loss: 0.2143 - val_accuracy: 0.9229
# Epoch 17/50
# 128/128 [==============================] - 0s 4ms/step - loss: 0.2338 - accuracy: 0.9137 - val_loss: 0.2107 - val_accuracy: 0.9199
# Epoch 18/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.2214 - accuracy: 0.9172 - val_loss: 0.2178 - val_accuracy: 0.9229
# Epoch 19/50
# 128/128 [==============================] - 0s 4ms/step - loss: 0.2128 - accuracy: 0.9289 - val_loss: 0.2007 - val_accuracy: 0.9385
# Epoch 20/50
# 128/128 [==============================] - 0s 4ms/step - loss: 0.2049 - accuracy: 0.9296 - val_loss: 0.1998 - val_accuracy: 0.9307
# Epoch 21/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1931 - accuracy: 0.9326 - val_loss: 0.2043 - val_accuracy: 0.9258
# Epoch 22/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1921 - accuracy: 0.9330 - val_loss: 0.1976 - val_accuracy: 0.9316
# Epoch 23/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1845 - accuracy: 0.9343 - val_loss: 0.1893 - val_accuracy: 0.9326
# Epoch 24/50
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1838 - accuracy: 0.9313 - val_loss: 0.2005 - val_accuracy: 0.9268
# Epoch 25/50
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1693 - accuracy: 0.9411 - val_loss: 0.1854 - val_accuracy: 0.9365
# Epoch 26/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1720 - accuracy: 0.9411 - val_loss: 0.1890 - val_accuracy: 0.9316
# Epoch 27/50
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1723 - accuracy: 0.9428 - val_loss: 0.1861 - val_accuracy: 0.9307
# Epoch 28/50
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1612 - accuracy: 0.9411 - val_loss: 0.1946 - val_accuracy: 0.9316
# Epoch 29/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1645 - accuracy: 0.9440 - val_loss: 0.2029 - val_accuracy: 0.9258
# Epoch 30/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1587 - accuracy: 0.9431 - val_loss: 0.1865 - val_accuracy: 0.9365
# Epoch 31/50
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1615 - accuracy: 0.9438 - val_loss: 0.1777 - val_accuracy: 0.9395
# Epoch 32/50
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1535 - accuracy: 0.9482 - val_loss: 0.1851 - val_accuracy: 0.9346
# Epoch 33/50
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1521 - accuracy: 0.9472 - val_loss: 0.2027 - val_accuracy: 0.9346
# Epoch 34/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1393 - accuracy: 0.9565 - val_loss: 0.1759 - val_accuracy: 0.9355
# Epoch 35/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1519 - accuracy: 0.9504 - val_loss: 0.1872 - val_accuracy: 0.9268
# Epoch 36/50
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1443 - accuracy: 0.9499 - val_loss: 0.1765 - val_accuracy: 0.9355
# Epoch 37/50
# 128/128 [==============================] - 1s 6ms/step - loss: 0.1295 - accuracy: 0.9567 - val_loss: 0.1899 - val_accuracy: 0.9375
# Epoch 38/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1439 - accuracy: 0.9558 - val_loss: 0.1770 - val_accuracy: 0.9453
# Epoch 39/50
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1326 - accuracy: 0.9536 - val_loss: 0.1802 - val_accuracy: 0.9404
# Epoch 40/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1341 - accuracy: 0.9543 - val_loss: 0.1839 - val_accuracy: 0.9395
# Epoch 41/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1224 - accuracy: 0.9580 - val_loss: 0.1850 - val_accuracy: 0.9326
# Epoch 42/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1263 - accuracy: 0.9585 - val_loss: 0.1764 - val_accuracy: 0.9355
# Epoch 43/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1190 - accuracy: 0.9624 - val_loss: 0.1777 - val_accuracy: 0.9414
# Epoch 44/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1188 - accuracy: 0.9572 - val_loss: 0.1678 - val_accuracy: 0.9424
# Epoch 45/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1244 - accuracy: 0.9555 - val_loss: 0.1998 - val_accuracy: 0.9355
# Epoch 46/50
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1075 - accuracy: 0.9651 - val_loss: 0.1788 - val_accuracy: 0.9385
# Epoch 47/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1192 - accuracy: 0.9592 - val_loss: 0.1722 - val_accuracy: 0.9404
# Epoch 48/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1108 - accuracy: 0.9619 - val_loss: 0.1761 - val_accuracy: 0.9395
# Epoch 49/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1117 - accuracy: 0.9614 - val_loss: 0.1777 - val_accuracy: 0.9355
# Epoch 50/50
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1131 - accuracy: 0.9585 - val_loss: 0.1883 - val_accuracy: 0.9375

# %%
plt.plot(range(epochs), history.history['loss'], label="Training Loss")
plt.plot(range(epochs), history.history['val_loss'], label="Validation Loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Loss Over Time")

plt.show()

# %% [markdown]
# Confusion matrix visualization:

# %%
y_true = np.array(y_test)
y_pred = np.array(model_RF.predict(x_test))
y_pred_xgb = np.array(model_XGB.predict(x_test))

cm = confusion_matrix(y_true, y_pred)
cm_xgb = confusion_matrix(y_true, y_pred_xgb)
plt.figure(figsize = (15,8))
sns.heatmap(cm, annot=True, fmt='g', cmap='gist_heat', cbar=True)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix for RF")
plt.show()
plt.figure(figsize = (15,8))
sns.heatmap(cm_xgb, annot=True, fmt='g', cmap='gist_heat',cbar=True)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix for XGB")
plt.show()
